# %%
import pandas as pd
import plotly.express as px
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
#Load the cleaned dataset
file_path = "colleges.csv"
colleges_df = pd.read_csv(file_path, index_col=0)
colleges_df.head()
# Out:
#            state  applicants_total  enrolled_total  perc_fresh_sat_scores  \
# collegeid
# 1              1            6142.0          1104.0                   15.0
# 2              1            5689.0          1773.0                    6.0
# 3              1            2054.0           651.0                   34.0
# 4              1           10245.0          1479.0                   18.0
# 5              1           30975.0          6454.0                   23.0
#
#            perc_fresh_act_scores  instate_price  outstate_price  \
# collegeid
# 1                           88.0        21849.0         27441.0
# 2                           93.0        22495.0         31687.0
# 3                           94.0        23466.0         35780.0
# 4                           87.0        18286.0         25222.0
# 5                           76.0        27000.0         41500.0
#
#            total_enrollment  ft_enrollment  pt_enrollment  ...  \
# ...

# %%
colleges_df.hvplot.scatter(x="enrolled_total", y="average_tuition")
# Out:
# :Scatter   [enrolled_total]   (average_tuition)

# %%
colleges_df.describe()
# Out:
#              state  applicants_total  enrolled_total  perc_fresh_sat_scores  \
# count  1111.000000       1111.000000     1111.000000            1111.000000
# mean     27.074707       7117.447345     1174.014401              53.042304
# std      14.108805       9372.837786     1373.805774              34.766104
# min       1.000000        152.000000       33.000000               0.000000
# 25%      15.000000       1696.500000      321.500000              15.000000
# 50%      28.000000       3670.000000      610.000000              64.000000
# 75%      39.000000       8151.000000     1417.500000              86.000000
# max      51.000000      72676.000000    10241.000000             100.000000
#
#        perc_fresh_act_scores  instate_price  outstate_price  total_enrollment  \
# count            1111.000000    1111.000000     1111.000000       1111.000000
# mean               54.340234   34598.635464    38958.018902       8395.122412
# ...

# %%
colleges_df
# Out:
#            state  applicants_total  enrolled_total  perc_fresh_sat_scores  \
# collegeid
# 1              1            6142.0          1104.0                   15.0
# 2              1            5689.0          1773.0                    6.0
# 3              1            2054.0           651.0                   34.0
# 4              1           10245.0          1479.0                   18.0
# 5              1           30975.0          6454.0                   23.0
# ...          ...               ...             ...                    ...
# 1107           5           12562.0           902.0                   93.0
# 1108          10           10804.0          2761.0                   83.0
# 1109           5            6960.0           756.0                   90.0
# 1110          10            1611.0           254.0                   69.0
# 1111          10            3195.0           562.0                   51.0
#
#            perc_fresh_act_scores  instate_price  outstate_price  \
# ...

# %%
colleges_train, colleges_test = train_test_split(colleges_df,random_state=1)

# %%
colleges_train.shape
# Out:
# (833, 40)

# %%
colleges_test.shape
# Out:
# (278, 40)

# %%
def get_splitclusters(k, data):
    # Create a copy of the DataFrame
    data = data.copy()

    # Initialize the K-Means model
    model = KMeans(n_clusters=k, random_state=0)

    # Fit the model
    model.fit(data)

    # Predict clusters
    predictions = model.predict(data)

    # Create return DataFrame with predicted clusters
    data["splitcluster"] = model.labels_

    return data

# %%
four_clusters_train=get_splitclusters(4, colleges_train)
four_clusters_train.head()
# Out:
#            state  applicants_total  enrolled_total  perc_fresh_sat_scores  \
# collegeid
# 630           33           57845.0          5207.0                   78.0
# 57             5           12741.0          1572.0                   91.0
# 485           24            1551.0           318.0                    5.0
# 986           44            4505.0           534.0                   59.0
# 55             5           16242.0          3139.0                   89.0
#
#            perc_fresh_act_scores  instate_price  outstate_price  \
# collegeid
# 630                         22.0        63540.0         63540.0
# 57                          32.0        22312.0         33472.0
# 485                         93.0        39750.0         39750.0
# 986                         40.0        48630.0         48630.0
# 55                          39.0        20682.0         31842.0
#
#            total_enrollment  ft_enrollment  pt_enrollment  ...  \
# ...

# %%
four_clusters_test=get_splitclusters(4, colleges_test)
four_clusters_test.head()
# Out:
#            state  applicants_total  enrolled_total  perc_fresh_sat_scores  \
# collegeid
# 664           33            3341.0           410.0                   82.0
# 738           36            1279.0           302.0                   14.0
# 127            7           27479.0          3755.0                   91.0
# 355           19             904.0           266.0                    3.0
# 1078          50            2167.0           544.0                    6.0
#
#            perc_fresh_act_scores  instate_price  outstate_price  \
# collegeid
# 664                          7.0        19284.0         28534.0
# 738                         99.0        35020.0         35020.0
# 127                         27.0        27244.0         46192.0
# 355                         93.0        23390.0         23390.0
# 1078                        87.0        46220.0         46220.0
#
#            total_enrollment  ft_enrollment  pt_enrollment  ...  \
# ...

# %%
colleges_split = four_clusters_train.append(four_clusters_test)
colleges_split.head()
# Out:
#            state  applicants_total  enrolled_total  perc_fresh_sat_scores  \
# collegeid
# 630           33           57845.0          5207.0                   78.0
# 57             5           12741.0          1572.0                   91.0
# 485           24            1551.0           318.0                    5.0
# 986           44            4505.0           534.0                   59.0
# 55             5           16242.0          3139.0                   89.0
#
#            perc_fresh_act_scores  instate_price  outstate_price  \
# collegeid
# 630                         22.0        63540.0         63540.0
# 57                          32.0        22312.0         33472.0
# 485                         93.0        39750.0         39750.0
# 986                         40.0        48630.0         48630.0
# 55                          39.0        20682.0         31842.0
#
#            total_enrollment  ft_enrollment  pt_enrollment  ...  \
# ...

# %%
colleges_split.to_csv('colleges_split.csv')

# %%
colleges_train.to_csv('colleges_train.csv')

# %%
def get_fullclusters(k, data):
    # Create a copy of the DataFrame
    data = data.copy()

    # Initialize the K-Means model
    model = KMeans(n_clusters=k, random_state=0)

    # Fit the model
    model.fit(data)

    # Predict clusters
    predictions = model.predict(data)

    # Create return DataFrame with predicted clusters
    data["fullcluster"] = model.labels_

    return data

# %%
colleges_4clusters=get_fullclusters(4, colleges_df)
colleges_4clusters.head()
# Out:
#            state  applicants_total  enrolled_total  perc_fresh_sat_scores  \
# collegeid
# 1              1            6142.0          1104.0                   15.0
# 2              1            5689.0          1773.0                    6.0
# 3              1            2054.0           651.0                   34.0
# 4              1           10245.0          1479.0                   18.0
# 5              1           30975.0          6454.0                   23.0
#
#            perc_fresh_act_scores  instate_price  outstate_price  \
# collegeid
# 1                           88.0        21849.0         27441.0
# 2                           93.0        22495.0         31687.0
# 3                           94.0        23466.0         35780.0
# 4                           87.0        18286.0         25222.0
# 5                           76.0        27000.0         41500.0
#
#            total_enrollment  ft_enrollment  pt_enrollment  ...  \
# ...

# %%
colleges_4clusters.hvplot.scatter(x="total_enrollment", y="average_tuition", by="fullcluster")
# Out:
# :NdOverlay   [fullcluster]
#    :Scatter   [total_enrollment]   (average_tuition)

# %%
colleges_split.hvplot.scatter(x="total_enrollment", y="average_tuition", by="splitcluster")
# Out:
# :NdOverlay   [splitcluster]
#    :Scatter   [total_enrollment]   (average_tuition)

# %%
colleges_4clusters.hvplot.scatter(x="instate_price", y="applicants_total", by="fullcluster")
# Out:
# :NdOverlay   [fullcluster]
#    :Scatter   [instate_price]   (applicants_total)

# %%
colleges_split.hvplot.scatter(x="instate_price", y="applicants_total", by="splitcluster")
# Out:
# :NdOverlay   [splitcluster]
#    :Scatter   [instate_price]   (applicants_total)
